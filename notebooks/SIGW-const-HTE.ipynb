# %% [markdown]
# ## SIGW with constant treatment effects and linear nuisance

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import math
import numpy as np

from coba.experiments  import Experiment, Result
from coba.environments import Environments
from coba.learners     import (RandomLearner,
                               EpsilonBanditLearner,
                               VowpalEpsilonLearner,
                               VowpalRegcbLearner,
                               VowpalSquarecbLearner,
                               LinUCBLearner)

from learners import (IGWBanditLearner,
                      SemiparametricIGWBanditLearner, MNA_SIGWBanditLearner)

# %% [markdown]
# ## Simulation 1
#
# - Number of arms: 2
# - Number of features: 10
# - Number of interactions: 10000
# - Std dev: 1/10
# - Contexts are sampled from a unit sphere.
# - Arm treatment effects (g): constant for all arms.
# - nuisance function (h): Linear.
# - Feature selection: False

# %%
from typing import Sequence

from coba.random       import CobaRandom
from coba.environments import LambdaSimulation, Context, Action

np.random.seed(42)

n_actions = 2
n_context_features = 10
n_interactions = 10000
r_noise_var = 1/100

theta = np.random.normal(size=(n_actions, n_context_features))
theta = theta / np.linalg.norm(theta, axis=1, keepdims=True)

onehot = np.zeros(n_actions)
onehot[0] = 1

rs = 0.5* (np.random.uniform(size=(n_actions)) + onehot)

def context(index: int) -> Context:
    context = np.random.normal(size=n_context_features)
    context = context / np.linalg.norm(context)
#     context = np.abs(context)
    return tuple(context)

def actions(index: int, context: Context) -> Sequence[Action]:
    return [tuple(1 if i == j else 0 for i in range(n_actions)) for j in range(n_actions)]

def rewards(index: int, context: Context, action: Action) -> float:
    v = np.dot(theta, np.array(context))
        
    h = np.mean(v)
   
    g = rs[np.argmax(action)]
    e = (np.random.uniform()-.5) * np.sqrt(12) * np.sqrt(r_noise_var)
    
    return h + g + e

environments = [LambdaSimulation(n_interactions, context, actions, rewards)]

epoch_schedule = 0
tuning_parameter = 1
do_feature_selection = False
learners     = [RandomLearner(),
                MNA_SIGWBanditLearner(epoch_schedule=epoch_schedule, tuning_parameter=tuning_parameter, do_feature_selection=do_feature_selection),
                IGWBanditLearner(epoch_schedule=epoch_schedule, tuning_parameter=tuning_parameter, do_feature_selection=do_feature_selection),
                SemiparametricIGWBanditLearner(epoch_schedule=epoch_schedule, tuning_parameter=tuning_parameter, do_feature_selection=do_feature_selection),]

Experiment(environments, learners).evaluate().plot_learners(sort="reward", span=n_interactions)
# Out:
# 2022-03-07 16:27:42 -- Processing chunk...
# 2022-03-07 16:27:42 --   * Recording Learner 0 parameters... (0.0 seconds) (completed)
# 2022-03-07 16:27:42 --   * Recording Learner 1 parameters... (0.0 seconds) (completed)
# 2022-03-07 16:27:42 --   * Recording Learner 2 parameters... (0.0 seconds) (completed)
# 2022-03-07 16:27:42 --   * Recording Learner 3 parameters... (0.0 seconds) (completed)
# 2022-03-07 16:27:43 --   * Loading LambdaSimulation... (0.93 seconds) (completed)
# 2022-03-07 16:27:43 --   * Creating Environment 0 from Loaded Source... (0.0 seconds) (completed)
# 2022-03-07 16:27:43 --   * Recording Environment 0 statistics... (0.0 seconds) (completed)
# 2022-03-07 16:27:43 --   * Evaluating Learner 0 on Environment 0... (0.18 seconds) (completed)
# 2022-03-07 16:27:47 --   * Evaluating Learner 1 on Environment 0... (4.15 seconds) (completed)
# 2022-03-07 16:27:50 --   * Evaluating Learner 2 on Environment 0... (2.94 seconds) (completed)
# 2022-03-07 16:27:53 --   * Evaluating Learner 3 on Environment 0... (3.12 seconds) (completed)

# %% [markdown]
# ## Simulation 2
#
# - Number of arms: 20
# - Number of features: 10
# - Number of interactions: 10000
# - Std dev: 1/10
# - Contexts are sampled from a unit sphere.
# - Arm treatment effects (g): constant for all arms.
# - nuisance function (h): Linear.
# - Feature selection: False

# %%
from typing import Sequence

from coba.random       import CobaRandom
from coba.environments import LambdaSimulation, Context, Action

np.random.seed(42)

n_actions = 20
n_context_features = 10
n_interactions = 10000
r_noise_var = 1/100

theta = np.random.normal(size=(n_actions, n_context_features))
theta = theta / np.linalg.norm(theta, axis=1, keepdims=True)

def context(index: int) -> Context:
    context = np.random.normal(size=n_context_features)
    context = context / np.linalg.norm(context)
    return tuple(context)

def actions(index: int, context: Context) -> Sequence[Action]:
    return [tuple(1 if i == j else 0 for i in range(n_actions)) for j in range(n_actions)]

def rewards(index: int, context: Context, action: Action) -> float:
    v = np.dot(theta, np.array(context))
    h = 0. 
        
    if context[0] > .25:
        h += 0
    else:
        h += -np.max(v)

    g = v[np.argmax(action)]   
    e = (np.random.uniform()-.5) * np.sqrt(12) * np.sqrt(r_noise_var)
    
    return h + g + e

environments = [LambdaSimulation(n_interactions, context, actions, rewards)]

epoch_schedule = 0
tuning_parameter = 1
do_feature_selection = False
learners     = [RandomLearner(),
                MNA_SIGWBanditLearner(epoch_schedule=epoch_schedule, tuning_parameter=tuning_parameter, do_feature_selection=do_feature_selection),
                IGWBanditLearner(epoch_schedule=epoch_schedule, tuning_parameter=tuning_parameter, do_feature_selection=do_feature_selection),
                SemiparametricIGWBanditLearner(epoch_schedule=epoch_schedule, tuning_parameter=tuning_parameter, do_feature_selection=do_feature_selection)]

Experiment(environments, learners).evaluate().plot_learners(sort="reward", span=n_interactions)
# Out:
# 2022-03-07 16:27:54 -- Processing chunk...
# 2022-03-07 16:27:54 --   * Recording Learner 0 parameters... (0.0 seconds) (completed)
# 2022-03-07 16:27:54 --   * Recording Learner 1 parameters... (0.0 seconds) (completed)
# 2022-03-07 16:27:54 --   * Recording Learner 2 parameters... (0.0 seconds) (completed)
# 2022-03-07 16:27:54 --   * Recording Learner 3 parameters... (0.0 seconds) (completed)
# 2022-03-07 16:27:58 --   * Loading LambdaSimulation... (4.09 seconds) (completed)
# 2022-03-07 16:27:58 --   * Creating Environment 0 from Loaded Source... (0.0 seconds) (completed)
# 2022-03-07 16:27:58 --   * Recording Environment 0 statistics... (0.0 seconds) (completed)
# 2022-03-07 16:27:58 --   * Evaluating Learner 0 on Environment 0... (0.37 seconds) (completed)
# 2022-03-07 16:28:09 --   * Evaluating Learner 1 on Environment 0... (11.01 seconds) (completed)
# 2022-03-07 16:28:22 --   * Evaluating Learner 2 on Environment 0... (12.55 seconds) (completed)
# 2022-03-07 16:28:28 --   * Evaluating Learner 3 on Environment 0... (6.59 seconds) (completed)
